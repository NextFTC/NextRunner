// %%
USE {
    repositories {
        maven("https://maven.zharel.me/releases")
    }

    dependencies {
        implementation("dev.nextftc.nextrunner:core:2.0.1")
    }
}

// %%
%use kandy

// %%
import com.acmerobotics.roadrunner.TEST_ACCEL_CONSTRAINT
import com.acmerobotics.roadrunner.TEST_PROFILE_PARAMS
import com.acmerobotics.roadrunner.TEST_TRAJECTORY_BUILDER_PARAMS
import com.acmerobotics.roadrunner.TEST_VEL_CONSTRAINT
import com.acmerobotics.roadrunner.randomAngle
import com.acmerobotics.roadrunner.randomPoint
import com.acmerobotics.roadrunner.randomPose
import com.acmerobotics.roadrunner.trajectories.TrajectoryBuilder

fun randomTraj() = TrajectoryBuilder(
    TEST_TRAJECTORY_BUILDER_PARAMS,
    randomPose(),
    0.0,
    TEST_VEL_CONSTRAINT,
    TEST_ACCEL_CONSTRAINT
)
    .splineTo(randomPoint(), randomAngle())
    .splineTo(randomPoint(), randomAngle())
    .splineTo(randomPoint(), randomAngle())
    .buildToComposite()

// %%
import com.acmerobotics.roadrunner.geometry.range
import com.acmerobotics.roadrunner.geometry.xs
import com.acmerobotics.roadrunner.geometry.ys
import com.acmerobotics.roadrunner.trajectories.CompositeTrajectory

val trajectory: CompositeTrajectory = randomTraj()
val length = trajectory.length
val samples = range(0.0, length, 100)

val points = samples.map { trajectory[it].position.value() }
val xs = points.xs()
val ys = points.ys()

plot {
    layout {
        // size = 512 to 512
    }
    path {
        x(xs) {
            scale = continuous(-72.0, 72.0)
        }
        y(ys) {
            scale = continuous(-72.0, 72.0)
        }
        color(samples) {
            scale = continuous(Color.RED..Color.BLUE)
            legend {
                name = "disp"
                breaks(format = "{d} in")
            }
        }
        points {
            x(listOf(xs.first(), xs.last()))
            y(listOf(ys.first(), ys.last()))
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;7eiXie&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-72.0,72.0]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[-72.0,72.0]
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient&quot;,
// &quot;high&quot;:&quot;#5470c6&quot;,
// &quot;low&quot;:&quot;#ee6666&quot;,
// &quot;name&quot;:&quot;disp&quot;,
// &quot;format&quot;:&quot;{d} in&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot